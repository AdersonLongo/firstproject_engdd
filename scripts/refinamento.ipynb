# %%
import duckdb
import pandas as pd
import os
from datetime import datetime as dt

# %%
con = duckdb.connect(database='dados_duckdb.db', read_only=False)

# %%
df = con.execute("SELECT table_schema, table_name, table_type FROM information_schema.tables").fetchdf()
df.head()
# Out:
# Empty DataFrame
# Columns: [table_schema, table_name, table_type]
# Index: []

# %%
df = con.execute("SELECT * FROM bronze_z0019").fetchdf()
df.head()
# Out:
# ---------------------------------------------------------------------------
# CatalogException                          Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df = con.execute("SELECT * FROM bronze_z0019").fetchdf()
#       2 df.head()
#
# CatalogException: Catalog Error: Table with name bronze_z0019 does not exist!
# Did you mean "duckdb_indexes"?
#
# LINE 1: SELECT * FROM bronze_z0019
#                       ^
